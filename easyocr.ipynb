# %% [markdown]
# # importing library

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open(r"D:\test\output3\maryam\190926_140400_6001685534_287587_FB_FGLPDF_1.png")

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1653x2338 at 0x19D41B1EC08>

# %%
import easyocr
reader = easyocr.Reader(['en'])

# %%
bounds = reader.readtext('96486_image_19.png')
bounds
# Out:
# [([[691, 77], [1155, 77], [1155, 167], [691, 167]],
#   'LUMBLAASIA',
#   0.5927686095237732),
#  ([[535, 179], [1200, 179], [1200, 234], [535, 234]],
#   'Columbia Asia Hospital Seremban',
#   0.435293972492218),
#  ([[695, 249], [1041, 249], [1041, 285], [695, 285]],
#   'LABORATORY REPORT',
#   0.8478357195854187),
#  ([[146, 332], [218, 332], [218, 358], [146, 358]],
#   'Name',
#   0.9880260825157166),
#  ([[344, 332], [504, 332], [504, 358], [344, 358]],
#   'CHAI PEI LENG',
#   0.12673798203468323),
#  ([[1257, 335], [1426, 335], [1426, 365], [1257, 365]],
#   '800714-05-5210',
#   0.5366286635398865),
#  ([[1119, 337], [1224, 337], [1224, 367], [1119, 367]],
#   'Passport',
#   0.9954983592033386),
#  ([[1024, 338], [1100, 338], [1100, 364], [1024, 364]],
#   'IC No.',
#   0.49067580699920654),
#  ([[146, 382], [204, 382], [204, 406], [146, 406]], 'MRN', 0.9588817358016968),
#  ([[344, 382], [530, 382], [530, 408], [344, 408]],
#   '5RB|/-0000137955',
#   0.5879704356193542),
#  ([[1024, 386], [1116, 386], [1116, 412], [1024, 412]],
#   'Visit No',
#   0.8405277132987976),
#  ([[1257, 388], [1457, 388], [1457, 414], [1257, 414]],
#   'Aooooo0OOO1-SRBN',
#   0.035521719604730606),
#  ([[144, 430], [288, 430], [288, 458], [144, 458]],
#   'Age/Gender',
#   0.8760340809822083),
#  ([[344, 430], [468, 430], [468, 456], [344, 456]],
#   '38Y 7M 11D',
#   0.1831309050321579),
#  ([[482, 432], [566, 432], [566, 458], [482, 458]],
#   'FEMALE',
#   0.9264128804206848),
#  ([[1024, 434], [1168, 434], [1168, 462], [1024, 462]],
#   'Received On',
#   0.6073343753814697),
#  ([[1257, 436], [1377, 436], [1377, 466], [1257, 466]],
#   '22/02/2019',
#   0.7513971924781799),
#  ([[1390, 438], [1468, 438], [1468, 464], [1390, 464]],
#   '7:36AM',
#   0.6686010956764221),
#  ([[144, 478], [228, 478], [228, 504], [144, 504]],
#   'Lab No',
#   0.9181817173957825),
#  ([[342, 478], [480, 478], [480, 506], [342, 506]],
#   '$0000276664',
#   0.741142749786377),
#  ([[1024, 484], [1170, 484], [1170, 512], [1024, 512]],
#   'Reported On',
#   0.8994380235671997),
#  ([[1258, 486], [1378, 486], [1378, 516], [1258, 516]],
#   '22/02/2019',
#   0.6360857486724854),
#  ([[1388, 486], [1468, 486], [1468, 512], [1388, 512]],
#   '9:17AM',
#   0.7339997887611389),
#  ([[143, 524], [280, 524], [280, 556], [143, 556]],
#   'Referred By',
#   0.7109374403953552),
#  ([[344, 525], [576, 525], [576, 553], [344, 553]],
#   'Dr. PANG MEI FOONG',
#   0.1458912491798401),
#  ([[1257, 532], [1458, 532], [1458, 562], [1257, 562]],
#   'MULTIDISCIPLNE1',
#   0.1250939667224884),
#  ([[1022, 534], [1222, 534], [1222, 560], [1022, 560]],
#   'Ward/Room/Bed',
#   0.43562906980514526),
#  ([[1472, 536], [1536, 536], [1536, 568], [1472, 568]],
#   '96(A)',
#   0.4475567638874054),
#  ([[1548, 538], [1592, 538], [1592, 566], [1548, 566]],
#   '96A',
#   0.5000016689300537),
#  ([[764, 660], [973, 660], [973, 703], [764, 703]],
#   'Biochemistry',
#   0.8963606953620911),
#  ([[158, 792], [296, 792], [296, 822], [158, 822]],
#   'Test Name',
#   0.7663713693618774),
#  ([[1037, 795], [1260, 795], [1260, 835], [1037, 835]],
#   'Reference Range',
#   0.713189959526062),
#  ([[606, 796], [692, 796], [692, 822], [606, 822]],
#   'Result',
#   0.7672320604324341),
#  ([[156, 847], [637, 847], [637, 888], [156, 888]],
#   'EXECILTTVE IELLNESSPBQEILE2',
#   0.0012039191788062453),
#  ([[158, 900], [230, 900], [230, 928], [158, 928]],
#   'BUSE',
#   0.9867000579833984),
#  ([[156, 940], [216, 940], [216, 964], [156, 964]],
#   'UREA',
#   0.9802848100662231),
#  ([[604, 942], [640, 942], [640, 968], [604, 968]], '3.7', 0.7345189452171326),
#  ([[1032, 942], [1157, 942], [1157, 972], [1032, 972]],
#   '(3.2 - 5.7)',
#   0.023492133244872093),
#  ([[650, 944], [730, 944], [730, 968], [650, 968]],
#   'mmolL',
#   0.512778103351593),
#  ([[153, 982], [243, 982], [243, 1008], [153, 1008]],
#   'SODIUM',
#   0.5357439517974854),
#  ([[602, 986], [646, 986], [646, 1012], [602, 1012]],
#   '138',
#   0.5737603902816772),
#  ([[654, 986], [734, 986], [734, 1012], [654, 1012]],
#   'mmolL',
#   0.23856297135353088),
#  ([[1050, 988], [1094, 988], [1094, 1012], [1050, 1012]],
#   '132',
#   0.6215959191322327),
#  ([[1108, 988], [1166, 988], [1166, 1016], [1108, 1016]],
#   '145 )',
#   0.11397496610879898),
#  ([[154, 1024], [278, 1024], [278, 1050], [154, 1050]],
#   'POTASSIUM',
#   0.9593967795372009),
#  ([[1031, 1028], [1088, 1028], [1088, 1058], [1031, 1058]],
#   '(3.5',
#   0.17146089673042297),
#  ([[602, 1030], [640, 1030], [640, 1054], [602, 1054]],
#   '3,9',
#   0.8547618389129639),
#  ([[648, 1030], [730, 1030], [730, 1056], [648, 1056]],
#   'mmolL',
#   0.33145833015441895),
#  ([[1102, 1030], [1154, 1030], [1154, 1060], [1102, 1060]],
#   '5.2 )',
#   0.3033331036567688),
#  ([[154, 1068], [266, 1068], [266, 1096], [154, 1096]],
#   'CHLORIDE',
#   0.9770119190216064),
#  ([[602, 1072], [644, 1072], [644, 1098], [602, 1098]],
#   '104',
#   0.7234911918640137),
#  ([[654, 1074], [732, 1074], [732, 1100], [654, 1100]],
#   'mmol/_',
#   0.24610690772533417),
#  ([[1048, 1074], [1082, 1074], [1082, 1102], [1048, 1102]],
#   '94',
#   0.8065047860145569),
#  ([[1094, 1074], [1152, 1074], [1152, 1104], [1094, 1104]],
#   '111 )',
#   0.30942994356155396),
#  ([[154, 1118], [364, 1118], [364, 1148], [154, 1148]],
#   'LIPIDS PROFILE',
#   0.2357148379087448),
#  ([[154, 1158], [374, 1158], [374, 1184], [154, 1184]],
#   'TOTAL CHOLESTEROL',
#   0.34235429763793945),
#  ([[602, 1160], [652, 1160], [652, 1186], [602, 1186]],
#   '5.20',
#   0.8745884895324707),
#  ([[1050, 1160], [1125, 1160], [1125, 1192], [1050, 1192]],
#   '<5.2 )',
#   0.13001936674118042),
#  ([[660, 1162], [740, 1162], [740, 1190], [660, 1190]],
#   'mmol/L',
#   0.681203305721283),
#  ([[154, 1200], [318, 1200], [318, 1226], [154, 1226]],
#   'TRIGLYCERIDES',
#   0.22358590364456177),
#  ([[600, 1204], [650, 1204], [650, 1230], [600, 1230]],
#   '0.75',
#   0.9000504016876221),
#  ([[1034, 1204], [1125, 1204], [1125, 1236], [1034, 1236]],
#   '(< 2.3 )',
#   0.10871725529432297),
#  ([[658, 1206], [740, 1206], [740, 1232], [658, 1232]],
#   'mmol/L',
#   0.33358824253082275),
#  ([[152, 1244], [344, 1244], [344, 1270], [152, 1270]],
#   'CHOLESTEROL LDL',
#   0.3945293724536896),
#  ([[600, 1248], [656, 1248], [656, 1274], [600, 1274]],
#   '3.43',
#   0.8279922604560852),
#  ([[663, 1249], [757, 1249], [757, 1275], [663, 1275]],
#   'mmol/L',
#   0.6487175822257996),
#  ([[1050, 1250], [1122, 1250], [1122, 1278], [1050, 1278]],
#   '<2,6 )',
#   0.12656694650650024),
#  ([[152, 1288], [348, 1288], [348, 1314], [152, 1314]],
#   'CHOLESTEROL HDL',
#   0.27441880106925964),
#  ([[600, 1290], [650, 1290], [650, 1316], [600, 1316]],
#   '1,43',
#   0.2581239342689514),
#  ([[658, 1292], [738, 1292], [738, 1318], [658, 1318]],
#   'mmoll',
#   0.4344697892665863),
#  ([[1050, 1294], [1122, 1294], [1122, 1322], [1050, 1322]],
#   '> 1.0)',
#   0.11214230954647064),
#  ([[152, 1328], [402, 1328], [402, 1360], [152, 1360]],
#   'TOTAL CHOLJHDL RATTO',
#   0.21813863515853882),
#  ([[600, 1334], [638, 1334], [638, 1360], [600, 1360]],
#   '3.6',
#   0.7065054774284363),
#  ([[1048, 1336], [1122, 1336], [1122, 1364], [1048, 1364]],
#   '<5,0)',
#   0.15043208003044128),
#  ([[152, 1380], [442, 1380], [442, 1412], [152, 1412]],
#   'LIVER FUNCTION TEST',
#   0.2064266800880432),
#  ([[150, 1418], [318, 1418], [318, 1444], [150, 1444]],
#   'TOTAL PROTEIN',
#   0.2771395444869995),
#  ([[600, 1424], [626, 1424], [626, 1448], [600, 1448]],
#   '77',
#   0.9002635478973389),
#  ([[636, 1426], [676, 1426], [676, 1454], [636, 1454]],
#   'g/l',
#   0.28911036252975464),
#  ([[1046, 1426], [1136, 1426], [1136, 1454], [1046, 1454]],
#   '64 - 83 )',
#   0.19394560158252716),
#  ([[152, 1464], [248, 1464], [248, 1488], [152, 1488]],
#   'ALBUMIN',
#   0.7405270934104919),
#  ([[598, 1468], [676, 1468], [676, 1498], [598, 1498]],
#   '45 g/L',
#   0.09209822863340378),
#  ([[1028, 1468], [1136, 1468], [1136, 1498], [1028, 1498]],
#   '( 34 ~ 48 )',
#   0.03102089837193489),
#  ([[150, 1506], [258, 1506], [258, 1532], [150, 1532]],
#   'GLOBULII',
#   0.45896100997924805),
#  ([[1091.0513167019494, 1508.1539501058485],
#    [1138.7604639068857, 1514.8253345077082],
#    [1133.9486832980506, 1543.8460498941515],
#    [1086.2395360931143, 1537.1746654922918]],
#   '42 )',
#   0.5621651411056519),
#  ([[598, 1510], [676, 1510], [676, 1542], [598, 1542]],
#   '32 g/L',
#   0.13145677745342255),
#  ([[1030, 1512], [1092, 1512], [1092, 1540], [1030, 1540]],
#   '( 18 -',
#   0.17875608801841736),
#  ([[150, 1550], [262, 1550], [262, 1576], [150, 1576]],
#   'AG RAIIO',
#   0.19487562775611877),
#  ([[598, 1554], [634, 1554], [634, 1580], [598, 1580]],
#   '1.4',
#   0.870334804058075),
#  ([[1046, 1556], [1150, 1556], [1150, 1586], [1046, 1586]],
#   '1,0 - 2.2 )',
#   0.06597144901752472),
#  ([[150, 1594], [330, 1594], [330, 1620], [150, 1620]],
#   'TOTAL BILIRUBII',
#   0.30641433596611023),
#  ([[596, 1597], [728, 1597], [728, 1626], [596, 1626]],
#   '17.3 umol/_',
#   0.05613657087087631),
#  ([[1026, 1600], [1084, 1600], [1084, 1628], [1026, 1628]],
#   '( 3.0',
#   0.18946249783039093),
#  ([[1096, 1600], [1160, 1600], [1160, 1628], [1096, 1628]],
#   '22.5)',
#   0.1244191974401474),
#  ([[149, 1634], [402, 1634], [402, 1664], [149, 1664]],
#   'ALIALINE PHOSPHATASE',
#   0.11777625232934952),
#  ([[596, 1642], [626, 1642], [626, 1666], [596, 1666]],
#   '58',
#   0.9289873838424683),
#  ([[636, 1642], [676, 1642], [676, 1670], [636, 1670]],
#   'U/L',
#   0.3634151220321655),
#  ([[1030, 1642], [1076, 1642], [1076, 1672], [1030, 1672]],
#   '( 35',
#   0.20226959884166718),
#  ([[1088, 1644], [1148, 1644], [1148, 1672], [1088, 1672]],
#   '110)',
#   0.31613942980766296),
#  ([[148, 1680], [512, 1680], [512, 1712], [148, 1712]],
#   'ASPARTAIE TRANSAMINASE (SGOT)',
#   0.14051437377929688),
#  ([[596, 1684], [688, 1684], [688, 1714], [596, 1714]],
#   '15 U/L',
#   0.24676014482975006),
#  ([[1044, 1686], [1076, 1686], [1076, 1712], [1044, 1712]],
#   '1S',
#   0.7627273201942444),
#  ([[1088, 1688], [1134, 1688], [1134, 1716], [1088, 1716]],
#   '32 )',
#   0.2938030958175659),
#  ([[146, 1721], [481, 1721], [481, 1757], [146, 1757]],
#   'ALANINE TRANSAMINASE (SGPT)',
#   0.10002578049898148),
#  ([[594, 1728], [626, 1728], [626, 1754], [594, 1754]],
#   '14',
#   0.9637018442153931),
#  ([[634, 1728], [676, 1728], [676, 1756], [634, 1756]],
#   'U/L',
#   0.3427630066871643),
#  ([[1026, 1730], [1122, 1730], [1122, 1760], [1026, 1760]],
#   '(0 - 35 )',
#   0.06935539841651917),
#  ([[146, 1768], [556, 1768], [556, 1800], [146, 1800]],
#   'GAMMA GLUTAMYL TRANSFERASE (GGT)',
#   0.08464649319648743),
#  ([[596, 1772], [626, 1772], [626, 1796], [596, 1796]],
#   '14',
#   0.9860453009605408),
#  ([[634, 1772], [676, 1772], [676, 1800], [634, 1800]],
#   'UlL',
#   0.10395827889442444),
#  ([[1026, 1774], [1122, 1774], [1122, 1802], [1026, 1802]],
#   '(0 - 38 )',
#   0.08097852766513824),
#  ([[148, 1818], [326, 1818], [326, 1848], [148, 1848]],
#   'RENAL PANEL',
#   0.17549248039722443),
#  ([[146, 1856], [248, 1856], [248, 1884], [146, 1884]],
#   'GLUCOSE',
#   0.9675332307815552),
#  ([[592, 1862], [630, 1862], [630, 1886], [592, 1886]],
#   '4.9',
#   0.7520049214363098),
#  ([[638, 1862], [720, 1862], [720, 1888], [638, 1888]],
#   'mmol/L',
#   0.7016487717628479),
#  ([[594, 1890], [809, 1890], [809, 1918], [594, 1918]],
#   'FASTIIG GLUCOSE (3.5',
#   0.05817512422800064),
#  ([[818, 1894], [852, 1894], [852, 1918], [818, 1918]],
#   '5.5',
#   0.8242144584655762),
#  ([[858, 1894], [938, 1894], [938, 1918], [858, 1918]],
#   'mmol/L)',
#   0.5475117564201355),
#  ([[592, 1914], [808, 1914], [808, 1940], [592, 1940]],
#   'RANDOM GLUCOSE (4.0',
#   0.18253852427005768),
#  ([[820, 1914], [942, 1914], [942, 1942], [820, 1942]],
#   'l.0 mmol/L)',
#   0.14967532455921173),
#  ([[146, 1946], [274, 1946], [274, 1972], [146, 1972]],
#   'CREATIIIIE',
#   0.3400745093822479),
#  ([[592, 1950], [706, 1950], [706, 1978], [592, 1978]],
#   'GS umol/L',
#   0.06318524479866028),
#  ([[1024, 1952], [1120, 1952], [1120, 1982], [1024, 1982]],
#   '(< 103 )',
#   0.0797925665974617),
#  ([[144, 1990], [202, 1990], [202, 2014], [144, 2014]],
#   'eGFR',
#   0.6288703680038452),
#  ([[592, 1994], [784, 1994], [784, 2022], [592, 2022]],
#   '92 mlmin/1.73m2',
#   0.019505983218550682),
#  ([[1024, 1996], [1108, 1996], [1108, 2026], [1024, 2026]],
#   '(2 60 )',
#   0.17049086093902588),
#  ([[146, 2032], [256, 2032], [256, 2058], [146, 2058]],
#   'URIC ACID',
#   0.6504526734352112),
#  ([[592, 2036], [632, 2036], [632, 2062], [592, 2062]],
#   '181',
#   0.32075202465057373),
#  ([[641, 2037], [716, 2037], [716, 2066], [641, 2066]],
#   'umol/L',
#   0.8149591684341431),
#  ([[1040, 2040], [1084, 2040], [1084, 2066], [1040, 2066]],
#   '140',
#   0.9616888165473938),
#  ([[1096, 2040], [1154, 2040], [1154, 2068], [1096, 2068]],
#   '340 )',
#   0.22130316495895386),
#  ([[144, 2076], [240, 2076], [240, 2102], [144, 2102]],
#   'CALCIUM',
#   0.6080527901649475),
#  ([[590, 2080], [638, 2080], [638, 2106], [590, 2106]],
#   '2.37',
#   0.625532329082489),
#  ([[648, 2082], [728, 2082], [728, 2108], [648, 2108]],
#   'mmoll',
#   0.24798433482646942),
#  ([[1038, 2084], [1078, 2084], [1078, 2110], [1038, 2110]],
#   '2.1',
#   0.8847168684005737),
#  ([[1090, 2084], [1144, 2084], [1144, 2112], [1090, 2112]],
#   '2.6 )',
#   0.3364952504634857),
#  ([[143, 2117], [409, 2117], [409, 2153], [143, 2153]],
#   'PHOSPHATE (INORGANIC)',
#   0.4344073534011841),
#  ([[592, 2124], [728, 2124], [728, 2152], [592, 2152]],
#   '1,29 mmol/L',
#   0.06151899695396423),
#  ([[1038, 2126], [1078, 2126], [1078, 2152], [1038, 2152]],
#   '0.8',
#   0.9589716196060181),
#  ([[1090, 2128], [1142, 2128], [1142, 2156], [1090, 2156]],
#   '1.5 )',
#   0.24448759853839874),
#  ([[72, 2186], [178, 2186], [178, 2214], [72, 2214]],
#   'Printed By',
#   0.8995939493179321),
#  ([[194, 2186], [282, 2186], [282, 2210], [194, 2210]],
#   'ZAMRI.Y',
#   0.42282193899154663),
#  ([[634, 2189], [1054, 2189], [1054, 2218], [634, 2218]],
#   'Report Printed On: 23/2/2019 10:13:13AM',
#   0.032245393842458725),
#  ([[1497, 2195], [1619, 2195], [1619, 2231], [1497, 2231]],
#   'Page 2 of5',
#   0.4178295433521271),
#  ([[289, 2237], [1393, 2237], [1393, 2278], [289, 2278]],
#   'No. 292, Jalan Haruan 2, Oakland Commercial Center, 7O3O0 Seremban Negeri Sembilan Darul Khusus, Malaysia.',
#   0.0008264613570645452),
#  ([[472, 2270], [652, 2270], [652, 2298], [472, 2298]],
#   'Tel: 606 6033988',
#   0.2059340476989746),
#  ([[672, 2271], [853, 2271], [853, 2300], [672, 2300]],
#   'Fax: 506 6013191',
#   0.14558766782283783),
#  ([[876, 2274], [1212, 2274], [1212, 2302], [876, 2302]],
#   'Website: wwwcolumnbiaasia.com',
#   0.08203882724046707)]

# %%
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(image, bounds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4a0b64e4f118> in <module>
#       6     return image
#       7
# ----> 8 draw_boxes('96486_image_19.png', bounds)
#
# <ipython-input-7-4a0b64e4f118> in draw_boxes(image, bounds, color, width)
#       1 def draw_boxes(image, bounds, color='yellow', width=2):
# ----> 2     draw = ImageDraw.Draw(image)
#       3     for bound in bounds:
#       4         p0, p1, p2, p3 = bound[0]
#       5         draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
#
# NameError: name 'ImageDraw' is not defined
